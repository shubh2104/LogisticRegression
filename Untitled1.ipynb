# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix, accuracy_score, classification_report

# %%
# Set up working directory and suppress warnings
warnings.filterwarnings("ignore")

# %%
# Load and inspect the dataset
df = pd.read_csv("data.csv")
print("Initial shape of the dataset:", df.shape)
# Out:
# Initial shape of the dataset: (100000, 28)

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name  Age        SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh   23  821000265  Scientist
# 1  5635         3392      2  Aaron Maashoh   23  821000265  Scientist
# 2  5636         3392      3  Aaron Maashoh   23  821000265  Scientist
# 3  5637         3392      4  Aaron Maashoh   23  821000265  Scientist
# 4  5638         3392      5  Aaron Maashoh   23  821000265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                  3  ...        Good
# 1       19114.12            1824.843333                  3  ...        Good
# 2       19114.12            1824.843333                  3  ...        Good
# 3       19114.12            1824.843333                  3  ...        Good
# 4       19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
# Data Cleaning
df_cleaned = df.drop_duplicates(subset=["Customer_ID"])
print("Shape of the dataset after removing duplicates:", df_cleaned.shape)
df_cleaned.drop(["ID", "Customer_ID", "Name", "SSN", "Type_of_Loan"], axis=1, inplace=True)
print("Shape of the dataset after dropping columns:", df_cleaned.shape)
# Out:
# Shape of the dataset after removing duplicates: (12500, 28)
# Shape of the dataset after dropping columns: (12500, 23)

# %%
# Data Preprocessing
df_encoded = pd.get_dummies(df_cleaned)
df_encoded.drop(["Occupation_Writer", "Credit_Mix_Standard", "Payment_of_Min_Amount_NM",
                 "Payment_Behaviour_Low_spent_Small_value_payments", "Credit_Score_Standard"], axis=1, inplace=True)

# %%
df_encoded.head()
# Out:
#     Month  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0       1   23       19114.12            1824.843333                  3
# 8       1   28       34847.84            3037.986667                  2
# 16      1   34      143162.64           12187.220000                  1
# 24      1   54       30689.89            2612.490833                  2
# 32      1   21       35547.71            2853.309167                  7
#
#     Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                 4              3            4                    3
# 8                 4              6            1                    3
# 16                5              8            3                    5
# 24                5              4            1                    0
# 32                5              5            0                    5
#
#     Num_of_Delayed_Payment  ...  Credit_Mix_Good  Payment_of_Min_Amount_No  \
# ...

# %%
# Splitting Data
dep = df_encoded["Monthly_Balance"]
ind = df_encoded.drop(["Monthly_Balance"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(ind, dep, train_size=0.75, random_state=42)

# %%
# Linear Regression
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
linear_pred = linear_model.predict(x_test)
r2 = r2_score(y_test, linear_pred)
mse = mean_squared_error(y_test, linear_pred)

# %%
residuals = y_test - linear_pred
plt.hist(residuals, bins=30, color='blue', alpha=0.7)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
plt.scatter(y_test, linear_pred, color='blue', alpha=0.7)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot: Actual vs. Predicted')
plt.show()

# %%
plt.hist(y_test, bins=30, color='blue', alpha=0.7, label='Actual')
plt.hist(linear_pred, bins=30, color='orange', alpha=0.5, label='Predicted')
plt.xlabel('Monthly Balance')
plt.ylabel('Frequency')
plt.title('Distribution of Actual and Predicted Monthly Balance')
plt.legend()
plt.show()

# %%
print("Linear Regression Model:")
print("R-Square Value:", round(r2, 4))
print("Mean Squared Error:", mse)
# Out:
# Linear Regression Model:
# R-Square Value: 0.6344
# Mean Squared Error: 14794.624268472113

# %%
# Logistic Regression
df_logistic = df

# %%
df_logistic.head()
# Out:
#      ID  Customer_ID  Month           Name  Age        SSN  Annual_Income  \
# 0  5634         3392      1  Aaron Maashoh   23  821000265       19114.12
# 1  5635         3392      2  Aaron Maashoh   23  821000265       19114.12
# 2  5636         3392      3  Aaron Maashoh   23  821000265       19114.12
# 3  5637         3392      4  Aaron Maashoh   23  821000265       19114.12
# 4  5638         3392      5  Aaron Maashoh   23  821000265       19114.12
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  ...  \
# 0            1824.843333                  3                4  ...
# 1            1824.843333                  3                4  ...
# 2            1824.843333                  3                4  ...
# 3            1824.843333                  3                4  ...
# 4            1824.843333                  3                4  ...
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit Num_Credit_Inquiries  \
# ...

# %%
df_logistic["Credit_Score"].replace({"Good": 1, "Standard": 2, "Poor": 3}, inplace=True)

# %%
dep_var = df_logistic["Credit_Score"]  # Assuming "Credit_Score" is the column you want to predict
ind_var = df_logistic.drop(["Credit_Score"], axis=1)
x_train_log, x_test_log, y_train_log, y_test_log = train_test_split(ind_var, dep_var, train_size=0.75, random_state=42)
logreg_model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
logreg_model.fit(x_train_log, y_train_log)
logreg_pred = logreg_model.predict(x_test_log)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 5
#       3 x_train_log, x_test_log, y_train_log, y_test_log = train_test_split(ind_var, dep_var, train_size=0.75, random_state=42)
#       4 logreg_model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
# ----> 5 logreg_model.fit(x_train_log, y_train_log)
#       6 logreg_pred = logreg_model.predict(x_test_log)
#
# File D:\New folder (2)\lib\site-packages\sklearn\linear_model\_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
# ...
