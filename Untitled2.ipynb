# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, confusion_matrix, accuracy_score, classification_report
import pickle

# %%
# Load the dataset
df = pd.read_csv("data.csv")
print("Initial shape of the dataset:", df.shape)
# Out:
# Initial shape of the dataset: (100000, 28)

# %%
# Option 1: Remove rows with missing values
df_cleaned = df.dropna()

# %%
# Option 2: Impute missing values (replace with mean or mode)
# For numerical columns
mean_values = df.mean()
df_imputed = df.fillna(mean_values)
# Out:
# C:\Users\SHUBHAM\AppData\Local\Temp\ipykernel_7660\3498642885.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = df.mean()

# %%
# For categorical columns
mode_values = df.mode().iloc[0]
df_imputed = df.fillna(mode_values)

# %%
# Step 1: Remove duplicate data entries based on customer ID
df = df.drop_duplicates(subset=["Customer_ID"])
df
# Out:
#            ID  Customer_ID  Month             Name  Age        SSN  \
# 0        5634         3392      1    Aaron Maashoh   23  821000265
# 8        5646         8625      1  Rick Rothackerj   28    4075839
# 16       5658        11708      1           Langep   34  486853974
# 24       5670        47249      1           Jasond   54   72316145
# 32       5682         7387      1           Deepaa   21  615067821
# ...       ...          ...    ...              ...  ...        ...
# 99960  155574        14124      1  Lucia Mutikanik   18  340857301
# 99968  155586         3862      1   Maria Sheahanb   44  868702218
# 99976  155598        44897      1   Chris Wickhamm   49  133167738
# 99984  155610        34304      1   Sarah McBridec   28   31350942
# 99992  155622        37932      1            Nicks   24   78735990
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          Scientist       19114.12            1824.843333                  3
# 8            Teacher       34847.84            3037.986667                  2
# 16          Engineer      143162.64           12187.220000                  1
# 24      Entrepreneur       30689.89            2612.490833                  2
# 32         Developer       35547.71            2853.309167                  7
# ...              ...            ...                    ...                ...
# 99960         Lawyer       42903.79            3468.315833                  0
# 99968  Media_Manager       16680.35            1528.029167                  1
# 99976         Writer       37188.10            3097.008333                  1
# 99984      Architect       20002.88            1929.906667                 10
# 99992       Mechanic       39628.99            3359.415833                  4
#
#        ...  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0      ...        Good            809.98                 26.822620
# 8      ...        Good            605.03                 24.464031
# 16     ...        Good           1303.01                 28.616735
# 24     ...        Good            632.46                 26.544229
# 32     ...    Standard            943.86                 39.797764
# ...    ...         ...               ...                       ...
# 99960  ...        Good           1079.48                 27.289440
# 99968  ...        Good            897.16                 39.868572
# 99976  ...        Good            620.64                 39.080823
# 99984  ...         Bad           3571.70                 22.895966
# 99992  ...        Good            502.38                 32.991333
#
#       Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                    265                     No            49.574949
# 8                    319                     No            18.816215
# 16                   213                     No           246.992320
# 24                   207                     No            16.415452
# 32                   368                    Yes             0.000000
# ...                  ...                    ...                  ...
# 99960                337                     No            34.975457
# 99968                254                     NM            41.113561
# 99976                357                     No            84.205949
# 99984                 68                    Yes            60.964772
# 99992                375                     No            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    21.465380   High_spent_Small_value_payments
# 8                    39.684018    Low_spent_Small_value_payments
# 16                  168.413703   High_spent_Small_value_payments
# 24                   29.393311    Low_spent_Large_value_payments
# 32                   37.643638  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99960                31.193919   High_spent_Small_value_payments
# 99968                40.893052   High_spent_Small_value_payments
# 99976                42.935566    Low_spent_Small_value_payments
# 99984                34.662906   High_spent_Large_value_payments
# 99992                24.028477    Low_spent_Small_value_payments
#
#       Monthly_Balance  Credit_Score
# 0          312.494089          Good
# 8          470.690627      Standard
# 16        1043.315978          Good
# 24         433.604773      Standard
# 32         288.605522      Standard
# ...               ...           ...
# 99960      493.341182          Good
# 99968      318.737378          Good
# 99976      291.619866          Good
# 99984      328.655224          Poor
# 99992      189.641080          Poor
#
# [12500 rows x 28 columns]

# %%
# Step 2: Eliminate unwanted variables like customer ID, name, etc.
unwanted_columns = ["ID", "Customer_ID", "Name", "SSN", "Type_of_Loan"]
df.drop(unwanted_columns, axis=1, inplace=True)
df
# Out:
#        Month  Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0          1   23      Scientist       19114.12            1824.843333
# 8          1   28        Teacher       34847.84            3037.986667
# 16         1   34       Engineer      143162.64           12187.220000
# 24         1   54   Entrepreneur       30689.89            2612.490833
# 32         1   21      Developer       35547.71            2853.309167
# ...      ...  ...            ...            ...                    ...
# 99960      1   18         Lawyer       42903.79            3468.315833
# 99968      1   44  Media_Manager       16680.35            1528.029167
# 99976      1   49         Writer       37188.10            3097.008333
# 99984      1   28      Architect       20002.88            1929.906667
# 99992      1   24       Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3                4              3            4
# 8                      2                4              6            1
# 16                     1                5              8            3
# 24                     2                5              4            1
# 32                     7                5              5            0
# ...                  ...              ...            ...          ...
# 99960                  0                4              6            1
# 99968                  1                1              5            4
# 99976                  1                4              5            3
# 99984                 10                8             29            5
# 99992                  4                6              7            2
#
#        Delay_from_due_date  ...  Credit_Mix  Outstanding_Debt  \
# 0                        3  ...        Good            809.98
# 8                        3  ...        Good            605.03
# 16                       5  ...        Good           1303.01
# 24                       0  ...        Good            632.46
# 32                       5  ...    Standard            943.86
# ...                    ...  ...         ...               ...
# 99960                   14  ...        Good           1079.48
# 99968                    4  ...        Good            897.16
# 99976                    7  ...        Good            620.64
# 99984                   35  ...         Bad           3571.70
# 99992                   23  ...        Good            502.38
#
#        Credit_Utilization_Ratio Credit_History_Age  Payment_of_Min_Amount  \
# 0                     26.822620                265                     No
# 8                     24.464031                319                     No
# 16                    28.616735                213                     No
# 24                    26.544229                207                     No
# 32                    39.797764                368                    Yes
# ...                         ...                ...                    ...
# 99960                 27.289440                337                     No
# 99968                 39.868572                254                     NM
# 99976                 39.080823                357                     No
# 99984                 22.895966                 68                    Yes
# 99992                 32.991333                375                     No
#
#        Total_EMI_per_month  Amount_invested_monthly  \
# 0                49.574949                21.465380
# 8                18.816215                39.684018
# 16              246.992320               168.413703
# 24               16.415452                29.393311
# 32                0.000000                37.643638
# ...                    ...                      ...
# 99960            34.975457                31.193919
# 99968            41.113561                40.893052
# 99976            84.205949                42.935566
# 99984            60.964772                34.662906
# 99992            35.104023                24.028477
#
#                       Payment_Behaviour  Monthly_Balance  Credit_Score
# 0       High_spent_Small_value_payments       312.494089          Good
# 8        Low_spent_Small_value_payments       470.690627      Standard
# 16      High_spent_Small_value_payments      1043.315978          Good
# 24       Low_spent_Large_value_payments       433.604773      Standard
# 32     High_spent_Medium_value_payments       288.605522      Standard
# ...                                 ...              ...           ...
# 99960   High_spent_Small_value_payments       493.341182          Good
# 99968   High_spent_Small_value_payments       318.737378          Good
# 99976    Low_spent_Small_value_payments       291.619866          Good
# 99984   High_spent_Large_value_payments       328.655224          Poor
# 99992    Low_spent_Small_value_payments       189.641080          Poor
#
# [12500 rows x 23 columns]

# %%
df1=pd.get_dummies(df)
df1.head()
# Out:
#     Month  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0       1   23       19114.12            1824.843333                  3
# 8       1   28       34847.84            3037.986667                  2
# 16      1   34      143162.64           12187.220000                  1
# 24      1   54       30689.89            2612.490833                  2
# 32      1   21       35547.71            2853.309167                  7
#
#     Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                 4              3            4                    3
# 8                 4              6            1                    3
# 16                5              8            3                    5
# 24                5              4            1                    0
# 32                5              5            0                    5
#
#     Num_of_Delayed_Payment  ...  Payment_of_Min_Amount_Yes  \
# 0                        7  ...                          0
# 8                        4  ...                          0
# 16                       8  ...                          0
# 24                       6  ...                          0
# 32                      15  ...                          1
#
#     Payment_Behaviour_High_spent_Large_value_payments  \
# 0                                                   0
# 8                                                   0
# 16                                                  0
# 24                                                  0
# 32                                                  0
#
#     Payment_Behaviour_High_spent_Medium_value_payments  \
# 0                                                   0
# 8                                                   0
# 16                                                  0
# 24                                                  0
# 32                                                  1
#
#     Payment_Behaviour_High_spent_Small_value_payments  \
# 0                                                   1
# 8                                                   0
# 16                                                  1
# 24                                                  0
# 32                                                  0
#
#     Payment_Behaviour_Low_spent_Large_value_payments  \
# 0                                                  0
# 8                                                  0
# 16                                                 0
# 24                                                 1
# 32                                                 0
#
#     Payment_Behaviour_Low_spent_Medium_value_payments  \
# 0                                                   0
# 8                                                   0
# 16                                                  0
# 24                                                  0
# 32                                                  0
#
#     Payment_Behaviour_Low_spent_Small_value_payments  Credit_Score_Good  \
# 0                                                  0                  1
# 8                                                  1                  0
# 16                                                 0                  1
# 24                                                 0                  0
# 32                                                 0                  0
#
#     Credit_Score_Poor  Credit_Score_Standard
# 0                   0                      0
# 8                   0                      1
# 16                  0                      0
# 24                  0                      1
# 32                  0                      1
#
# [5 rows x 48 columns]

# %%
df1.drop(["Occupation_Writer","Credit_Mix_Standard","Payment_of_Min_Amount_NM",
       "Payment_Behaviour_Low_spent_Small_value_payments","Credit_Score_Standard"],axis=1,inplace=True)
df1
# Out:
#        Month  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          1   23       19114.12            1824.843333                  3
# 8          1   28       34847.84            3037.986667                  2
# 16         1   34      143162.64           12187.220000                  1
# 24         1   54       30689.89            2612.490833                  2
# 32         1   21       35547.71            2853.309167                  7
# ...      ...  ...            ...                    ...                ...
# 99960      1   18       42903.79            3468.315833                  0
# 99968      1   44       16680.35            1528.029167                  1
# 99976      1   49       37188.10            3097.008333                  1
# 99984      1   28       20002.88            1929.906667                 10
# 99992      1   24       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                    4              3            4                    3
# 8                    4              6            1                    3
# 16                   5              8            3                    5
# 24                   5              4            1                    0
# 32                   5              5            0                    5
# ...                ...            ...          ...                  ...
# 99960                4              6            1                   14
# 99968                1              5            4                    4
# 99976                4              5            3                    7
# 99984                8             29            5                   35
# 99992                6              7            2                   23
#
#        Num_of_Delayed_Payment  ...  Credit_Mix_Good  Payment_of_Min_Amount_No  \
# 0                           7  ...                1                         1
# 8                           4  ...                1                         1
# 16                          8  ...                1                         1
# 24                          6  ...                1                         1
# 32                         15  ...                0                         0
# ...                       ...  ...              ...                       ...
# 99960                       0  ...                1                         1
# 99968                       0  ...                1                         0
# 99976                      12  ...                1                         1
# 99984                      25  ...                0                         0
# 99992                       6  ...                1                         1
#
#        Payment_of_Min_Amount_Yes  \
# 0                              0
# 8                              0
# 16                             0
# 24                             0
# 32                             1
# ...                          ...
# 99960                          0
# 99968                          0
# 99976                          0
# 99984                          1
# 99992                          0
#
#        Payment_Behaviour_High_spent_Large_value_payments  \
# 0                                                      0
# 8                                                      0
# 16                                                     0
# 24                                                     0
# 32                                                     0
# ...                                                  ...
# 99960                                                  0
# 99968                                                  0
# 99976                                                  0
# 99984                                                  1
# 99992                                                  0
#
#        Payment_Behaviour_High_spent_Medium_value_payments  \
# 0                                                      0
# 8                                                      0
# 16                                                     0
# 24                                                     0
# 32                                                     1
# ...                                                  ...
# 99960                                                  0
# 99968                                                  0
# 99976                                                  0
# 99984                                                  0
# 99992                                                  0
#
#        Payment_Behaviour_High_spent_Small_value_payments  \
# 0                                                      1
# 8                                                      0
# 16                                                     1
# 24                                                     0
# 32                                                     0
# ...                                                  ...
# 99960                                                  1
# 99968                                                  1
# 99976                                                  0
# 99984                                                  0
# 99992                                                  0
#
#        Payment_Behaviour_Low_spent_Large_value_payments  \
# 0                                                     0
# 8                                                     0
# 16                                                    0
# 24                                                    1
# 32                                                    0
# ...                                                 ...
# 99960                                                 0
# 99968                                                 0
# 99976                                                 0
# 99984                                                 0
# 99992                                                 0
#
#        Payment_Behaviour_Low_spent_Medium_value_payments  Credit_Score_Good  \
# 0                                                      0                  1
# 8                                                      0                  0
# 16                                                     0                  1
# 24                                                     0                  0
# 32                                                     0                  0
# ...                                                  ...                ...
# 99960                                                  0                  1
# 99968                                                  0                  1
# 99976                                                  0                  1
# 99984                                                  0                  0
# 99992                                                  0                  0
#
#        Credit_Score_Poor
# 0                      0
# 8                      0
# 16                     0
# 24                     0
# 32                     0
# ...                  ...
# 99960                  0
# 99968                  0
# 99976                  0
# 99984                  1
# 99992                  1
#
# [12500 rows x 43 columns]

# %%
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12500 entries, 0 to 99992
# Data columns (total 43 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Month                                               12500 non-null  int64
#  1   Age                                                 12500 non-null  int64
#  2   Annual_Income                                       12500 non-null  float64
#  3   Monthly_Inhand_Salary                               12500 non-null  float64
#  4   Num_Bank_Accounts                                   12500 non-null  int64
#  5   Num_Credit_Card                                     12500 non-null  int64
#  6   Interest_Rate                                       12500 non-null  int64
#  7   Num_of_Loan                                         12500 non-null  int64
#  8   Delay_from_due_date                                 12500 non-null  int64
#  9   Num_of_Delayed_Payment                              12500 non-null  int64
#  10  Changed_Credit_Limit                                12500 non-null  float64
#  11  Num_Credit_Inquiries                                12500 non-null  int64
#  12  Outstanding_Debt                                    12500 non-null  float64
#  13  Credit_Utilization_Ratio                            12500 non-null  float64
#  14  Credit_History_Age                                  12500 non-null  int64
#  15  Total_EMI_per_month                                 12500 non-null  float64
#  16  Amount_invested_monthly                             12500 non-null  float64
#  17  Monthly_Balance                                     12500 non-null  float64
#  18  Occupation_Accountant                               12500 non-null  uint8
#  19  Occupation_Architect                                12500 non-null  uint8
#  20  Occupation_Developer                                12500 non-null  uint8
#  21  Occupation_Doctor                                   12500 non-null  uint8
#  22  Occupation_Engineer                                 12500 non-null  uint8
#  23  Occupation_Entrepreneur                             12500 non-null  uint8
#  24  Occupation_Journalist                               12500 non-null  uint8
#  25  Occupation_Lawyer                                   12500 non-null  uint8
#  26  Occupation_Manager                                  12500 non-null  uint8
#  27  Occupation_Mechanic                                 12500 non-null  uint8
#  28  Occupation_Media_Manager                            12500 non-null  uint8
#  29  Occupation_Musician                                 12500 non-null  uint8
#  30  Occupation_Scientist                                12500 non-null  uint8
#  31  Occupation_Teacher                                  12500 non-null  uint8
#  32  Credit_Mix_Bad                                      12500 non-null  uint8
#  33  Credit_Mix_Good                                     12500 non-null  uint8
#  34  Payment_of_Min_Amount_No                            12500 non-null  uint8
#  35  Payment_of_Min_Amount_Yes                           12500 non-null  uint8
#  36  Payment_Behaviour_High_spent_Large_value_payments   12500 non-null  uint8
#  37  Payment_Behaviour_High_spent_Medium_value_payments  12500 non-null  uint8
#  38  Payment_Behaviour_High_spent_Small_value_payments   12500 non-null  uint8
#  39  Payment_Behaviour_Low_spent_Large_value_payments    12500 non-null  uint8
#  40  Payment_Behaviour_Low_spent_Medium_value_payments   12500 non-null  uint8
#  41  Credit_Score_Good                                   12500 non-null  uint8
#  42  Credit_Score_Poor                                   12500 non-null  uint8
# dtypes: float64(8), int64(10), uint8(25)
# memory usage: 2.1 MB

# %%
# Step 4: Splitting the dataset for regression analysis
dep = df_dummies["Monthly_Balance"]
ind = df_dummies.drop(["Monthly_Balance"], axis=1)
ind
# Out:
#        Month  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          1   23       19114.12            1824.843333                  3
# 8          1   28       34847.84            3037.986667                  2
# 16         1   34      143162.64           12187.220000                  1
# 24         1   54       30689.89            2612.490833                  2
# 32         1   21       35547.71            2853.309167                  7
# ...      ...  ...            ...                    ...                ...
# 99960      1   18       42903.79            3468.315833                  0
# 99968      1   44       16680.35            1528.029167                  1
# 99976      1   49       37188.10            3097.008333                  1
# 99984      1   28       20002.88            1929.906667                 10
# 99992      1   24       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                    4              3            4                    3
# 8                    4              6            1                    3
# 16                   5              8            3                    5
# 24                   5              4            1                    0
# 32                   5              5            0                    5
# ...                ...            ...          ...                  ...
# 99960                4              6            1                   14
# 99968                1              5            4                    4
# 99976                4              5            3                    7
# 99984                8             29            5                   35
# 99992                6              7            2                   23
#
#        Num_of_Delayed_Payment  ...  Occupation_Journalist  Occupation_Lawyer  \
# 0                           7  ...                      0                  0
# 8                           4  ...                      0                  0
# 16                          8  ...                      0                  0
# 24                          6  ...                      0                  0
# 32                         15  ...                      0                  0
# ...                       ...  ...                    ...                ...
# 99960                       0  ...                      0                  1
# 99968                       0  ...                      0                  0
# 99976                      12  ...                      0                  0
# 99984                      25  ...                      0                  0
# 99992                       6  ...                      0                  0
#
#       Occupation_Manager  Occupation_Mechanic  Occupation_Media_Manager  \
# 0                      0                    0                         0
# 8                      0                    0                         0
# 16                     0                    0                         0
# 24                     0                    0                         0
# 32                     0                    0                         0
# ...                  ...                  ...                       ...
# 99960                  0                    0                         0
# 99968                  0                    0                         1
# 99976                  0                    0                         0
# 99984                  0                    0                         0
# 99992                  0                    1                         0
#
#        Occupation_Musician  Occupation_Scientist  Occupation_Teacher  \
# 0                        0                     1                   0
# 8                        0                     0                   1
# 16                       0                     0                   0
# 24                       0                     0                   0
# 32                       0                     0                   0
# ...                    ...                   ...                 ...
# 99960                    0                     0                   0
# 99968                    0                     0                   0
# 99976                    0                     0                   0
# 99984                    0                     0                   0
# 99992                    0                     0                   0
#
#        Occupation_Writer  Credit_Score_Poor
# 0                      0                  0
# 8                      0                  0
# 16                     0                  0
# 24                     0                  0
# 32                     0                  0
# ...                  ...                ...
# 99960                  0                  0
# 99968                  0                  0
# 99976                  1                  0
# 99984                  0                  1
# 99992                  0                  1
#
# [12500 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ind,dep,train_size=0.75)

# %%
# Step 6: Linear Regression model
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
pred_linear = linear_model.predict(x_test)
r2_linear = r2_score(y_test, pred_linear)
plt.figure(figsize=(10, 5))
sns.regplot(y_test, pred_linear, color="blue")
print("Linear Regression - R-Square:", round(r2_linear, 4))
print("Linear Regression - RMSE:", mean_squared_error(y_test, pred_linear, squared=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 3
#       1 # Step 6: Linear Regression model
#       2 linear_model = LinearRegression()
# ----> 3 linear_model.fit(x_train, y_train)
#       4 pred_linear = linear_model.predict(x_test)
#       5 r2_linear = r2_score(y_test, pred_linear)
#
# File D:\New folder (2)\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# File D:\New folder (2)\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File D:\New folder (2)\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Standard'

# %%
# Step 5: Split the dataset for regression analysis
dep = df_encoded["Monthly_Balance"]
ind = df_encoded.drop(["Monthly_Balance"], axis=1)

x_train, x_test, y_train, y_test = train_test_split(ind, dep, train_size=0.75)

# %%
# Step 6: Linear Regression model
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
pred_linear = linear_model.predict(x_test)
r2_linear = r2_score(y_test, pred_linear)

plt.figure(figsize=(10, 5))
sns.regplot(pred_linear, y_test, color="blue")  # Corrected plot arguments

print("Linear Regression - R-Square:", round(r2_linear, 4))
print("Linear Regression - RMSE:", mean_squared_error(y_test, pred_linear, squared=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Step 6: Linear Regression model
#       2 linear_model = LinearRegression()
# ----> 3 linear_model.fit(x_train, y_train)
#       4 pred_linear = linear_model.predict(x_test)
#       5 r2_linear = r2_score(y_test, pred_linear)
#
# File D:\New folder (2)\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# File D:\New folder (2)\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File D:\New folder (2)\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Bad'

# %%
df_encoded
# Out:
#        Month  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          1   23       19114.12            1824.843333                  3
# 8          1   28       34847.84            3037.986667                  2
# 16         1   34      143162.64           12187.220000                  1
# 24         1   54       30689.89            2612.490833                  2
# 32         1   21       35547.71            2853.309167                  7
# ...      ...  ...            ...                    ...                ...
# 99960      1   18       42903.79            3468.315833                  0
# 99968      1   44       16680.35            1528.029167                  1
# 99976      1   49       37188.10            3097.008333                  1
# 99984      1   28       20002.88            1929.906667                 10
# 99992      1   24       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                    4              3            4                    3
# 8                    4              6            1                    3
# 16                   5              8            3                    5
# 24                   5              4            1                    0
# 32                   5              5            0                    5
# ...                ...            ...          ...                  ...
# 99960                4              6            1                   14
# 99968                1              5            4                    4
# 99976                4              5            3                    7
# 99984                8             29            5                   35
# 99992                6              7            2                   23
#
#        Num_of_Delayed_Payment  ...  Credit_Mix_Good  Payment_of_Min_Amount_No  \
# 0                           7  ...                1                         1
# 8                           4  ...                1                         1
# 16                          8  ...                1                         1
# 24                          6  ...                1                         1
# 32                         15  ...                0                         0
# ...                       ...  ...              ...                       ...
# 99960                       0  ...                1                         1
# 99968                       0  ...                1                         0
# 99976                      12  ...                1                         1
# 99984                      25  ...                0                         0
# 99992                       6  ...                1                         1
#
#        Payment_of_Min_Amount_Yes  \
# 0                              0
# 8                              0
# 16                             0
# 24                             0
# 32                             1
# ...                          ...
# 99960                          0
# 99968                          0
# 99976                          0
# 99984                          1
# 99992                          0
#
#        Payment_Behaviour_High_spent_Large_value_payments  \
# 0                                                      0
# 8                                                      0
# 16                                                     0
# 24                                                     0
# 32                                                     0
# ...                                                  ...
# 99960                                                  0
# 99968                                                  0
# 99976                                                  0
# 99984                                                  1
# 99992                                                  0
#
#        Payment_Behaviour_High_spent_Medium_value_payments  \
# 0                                                      0
# 8                                                      0
# 16                                                     0
# 24                                                     0
# 32                                                     1
# ...                                                  ...
# 99960                                                  0
# 99968                                                  0
# 99976                                                  0
# 99984                                                  0
# 99992                                                  0
#
#        Payment_Behaviour_High_spent_Small_value_payments  \
# 0                                                      1
# 8                                                      0
# 16                                                     1
# 24                                                     0
# 32                                                     0
# ...                                                  ...
# 99960                                                  1
# 99968                                                  1
# 99976                                                  0
# 99984                                                  0
# 99992                                                  0
#
#        Payment_Behaviour_Low_spent_Large_value_payments  \
# 0                                                     0
# 8                                                     0
# 16                                                    0
# 24                                                    1
# 32                                                    0
# ...                                                 ...
# 99960                                                 0
# 99968                                                 0
# 99976                                                 0
# 99984                                                 0
# 99992                                                 0
#
#        Payment_Behaviour_Low_spent_Medium_value_payments  Credit_Score_Good  \
# 0                                                      0                  1
# 8                                                      0                  0
# 16                                                     0                  1
# 24                                                     0                  0
# 32                                                     0                  0
# ...                                                  ...                ...
# 99960                                                  0                  1
# 99968                                                  0                  1
# 99976                                                  0                  1
# 99984                                                  0                  0
# 99992                                                  0                  0
#
#        Credit_Score_Poor
# 0                      0
# 8                      0
# 16                     0
# 24                     0
# 32                     0
# ...                  ...
# 99960                  0
# 99968                  0
# 99976                  0
# 99984                  1
# 99992                  1
#
# [12500 rows x 43 columns]

# %%
# Logistic Regression
df_logistic = df.copy()
df_logistic["Credit_Score"] = df_logistic["Credit_Score"].replace({"Good": 1, "Standard": 2, "Poor": 3})
df_logistic=pd.get_dummies(df_logistic)
dep_var = df_logistic["Credit_Score"]
ind_var = df_logistic.drop(["Credit_Score"], axis=1)
x_train_log, x_test_log, y_train_log, y_test_log = train_test_split(ind_var, dep_var, train_size=0.75, random_state=42)

# %%
# Logistic Regression Model
logreg_model = LogisticRegression()
logreg_model.fit(x_train_log, y_train_log)
logreg_pred = logreg_model.predict(x_test_log)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Logistic Regression Model
#       2 logreg_model = LogisticRegression()
# ----> 3 logreg_model.fit(x_train_log, y_train_log)
#       4 logreg_pred = logreg_model.predict(x_test_log)
#
# File D:\New folder (2)\lib\site-packages\sklearn\linear_model\_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#
# File D:\New folder (2)\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File D:\New folder (2)\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Julienx'

# %%
# Logistic Regression Model
logreg_model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
logreg_model.fit(x_train_log, y_train_log)
logreg_pred = logreg_model.predict(x_test_log)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Logistic Regression Model
#       2 logreg_model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
# ----> 3 logreg_model.fit(x_train_log, y_train_log)
#       4 logreg_pred = logreg_model.predict(x_test_log)
#
# File D:\New folder (2)\lib\site-packages\sklearn\linear_model\_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#
# File D:\New folder (2)\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File D:\New folder (2)\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File D:\New folder (2)\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Julienx'
